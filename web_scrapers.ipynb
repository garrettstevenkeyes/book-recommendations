# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import csv
import numpy as np
import time
from tqdm import tqdm_notebook as tqdm
import re
from urllib.request import Request, urlopen

# %% [markdown]
# # Scrape Goodreads

# %%
number_of_pages = list(range(1,3))
all_books = []

for number in number_of_pages:
    page = requests.get(f'https://www.goodreads.com/list/show/7.Best_Books_of_the_21st_Century?page={number}')
    soup = BeautifulSoup(page.content, 'html.parser')
    table = soup.find('table', attrs={'class': 'tableList js-dataTooltip'})
    table_body = table.find_all('tr')

    for entry in table_body:
        try:
            hrefs = entry.find_all(href=True)

            #get the book title
            title = hrefs[0]['title']

            #get the book author
            author = hrefs[2].get_text()

            #get the book link
            link = hrefs[0]['href']

            #get the description of the book through its link
            page2 = requests.get(f'https://www.goodreads.com{link}')
            soup2 = BeautifulSoup(page2.content, 'html.parser')

            #select the description box
            description_box = soup2.find_all('div', attrs={'id': 'description'})

            #get the summary of each book
            book_text = description_box[0].find_all('span')[1].get_text()

            #book pictures
            image_box = soup2.find_all('img', attrs={'id' : 'coverImage'})
            picture = image_box[0]['src']

            #number of pages
            page_box = soup2.find_all('span', attrs={'itemprop':'numberOfPages'})
            page_count = page_box[0].get_text()

            #genres
            genre_box = soup2.find_all('a', attrs={'class':'actionLinkLite bookPageGenreLink'})
            genre_list = []
            for genre in genre_box:
                genre_list.append(genre.get_text())

            #add to dictionary
            row_profile = {'name':title, 'author':author, 'link':link, 'text':book_text,
                           'picture':picture, 'page number':page_count, 'genres':genre_list}

            all_books.append(row_profile)

            print(title)
        except:
            pass
    print(f'page {number} is done!')
    
f = open("books.csv", "w")
writer = csv.DictWriter(f, fieldnames=['name', 'author', 'link', 'text', 'picture', 'page number', 'genres'])
writer.writeheader()
writer.writerows(all_books)
f.close()
# Out:
# Harry Potter and the Deathly Hallows
# The Hunger Games
# The Kite Runner
# The Book Thief
# Harry Potter and the Half-Blood Prince
# Harry Potter and the Order of the Phoenix
# The Help
# A Thousand Splendid Suns
# Catching Fire
# The Girl with the Dragon Tattoo
# The Time Traveler's Wife
# The Fault in Our Stars
# The Da Vinci Code
# The Road
# Water for Elephants
# The Curious Incident of the Dog in the Night-Time
# Mockingjay
# The Lovely Bones
# Middlesex
# Divergent
# Atonement
# The Lightning Thief
# The Shadow of the Wind
# City of Bones
# American Gods
# The Secret Life of Bees
# Extremely Loud and Incredibly Close
# The Glass Castle
# My Sister's Keeper
# Angels & Demons
# Never Let Me Go
# The Girl Who Played with Fire
# Cloud Atlas
# The Host
# Breaking Dawn
# The Guernsey Literary and Potato Peel Pie Society
# Eclipse
# The Girl Who Kicked the Hornet's Nest
# Eat, Pray, Love
# New Moon
# City of Glass
# Kafka on the Shore
# The Name of the Wind
# The Graveyard Book
# Room
# City of Ashes
# Freakonomics: A Rogue Economist Explores the Hidden Side of Everything
# The Brief Wondrous Life of Oscar Wao
# The Corrections
# The Devil in the White City: Murder, Magic, and Madness at the Fair That Changed America
# The Thirteenth Tale
# The Night Circus
# Marley and Me: Life and Love With the World's Worst Dog
# Gone Girl
# Vampire Academy
# The Other Boleyn Girl
# The Art of Racing in the Rain
# Everything Is Illuminated
# No Country for Old Men
# Bel Canto
# The Complete Persepolis
# The Namesake
# Oryx and Crake
# Blossom in Winter
# Snow Flower and the Secret Fan
# A Short History of Nearly Everything
# Jonathan Strange & Mr Norrell
# The Memory Keeper's Daughter
# Lamb: The Gospel According to Biff, Christ's Childhood Pal
# Three Cups of Tea: One Man's Mission to Promote Peace ... One School at a Time
# The God Delusion
# The Shack
# Unbroken: A World War II Story of Survival, Resilience and Redemption
# Sarah's Key
# All the Light We Cannot See
# Nineteen Minutes
# The Omnivore's Dilemma: A Natural History of Four Meals
# The History of Love
# What Is the What
# Blink: The Power of Thinking Without Thinking
# The White Tiger
# Dress Your Family in Corduroy and Denim
# The Story of Edgar Sawtelle
# Empire Falls
# Gilead
# Looking for Alaska
# John Adams
# Eats, Shoots & Leaves: The Zero Tolerance Approach to Punctuation
# The Year of Magical Thinking
# A Million Little Pieces
# God Is Not Great: How Religion Poisons Everything
# Insurgent
# 11/22/63
# People of the Book
# Cutting for Stone
# page 1 is done!
# Ready Player One
# Unaccustomed Earth
# Clockwork Angel
# Under the Banner of Heaven: A Story of Violent Faith
# Animal, Vegetable, Miracle: A Year of Food Life
# The Immortal Life of Henrietta Lacks
# The Goldfinch
# We Need to Talk About Kevin
# Eragon
# The Five People You Meet in Heaven
# On Beauty
# The Known World
# World Without End
# A Dance with Dragons
# The Martian
# Coraline
# Graceling
# Freedom
# Year of Wonders
# The Last Olympian
# The Maze Runner
# The Millennium Trilogy
# A Feast for Crows
# The Elegance of the Hedgehog
# Thirteen Reasons Why
# Seabiscuit: An American Legend
# The Sea of Monsters
# World War Z: An Oral History of the Zombie War
# Shadow Kiss
# Shantaram
# The Last Lecture
# Frostbite
# 2666
# The Lost Symbol
# Reading Lolita in Tehran: A Memoir in Books
# Olive Kitteridge
# The Battle of the Labyrinth
# The Tales of Beedle the Bard
# Me Before You
# Miss Peregrine's Home for Peculiar Children
# The Plot Against America
# Uglies
# Wolf Hall
# Peace Like a River
# City of Fallen Angels
# Hush, Hush
# Blood Promise
# Let the Great World Spin
# Nickel and Dimed: On (Not) Getting by in America
# A Visit from the Goon Squad
# Inkheart
# The Ocean at the End of the Lane
# Running with Scissors
# The Invention of Hugo Cabret
# The Yiddish Policemen's Union
# 1Q84
# The Passage
# Hotel on the Corner of Bitter and Sweet
# The Eyre Affair
# Blood River: A Journey to Africa's Broken Heart
# The Lost Hero
# Shutter Island
# Black Swan Green
# The Forgotten Garden
# Fingersmith
# Mystic River
# Delirium
# Half of a Yellow Sun
# Fast Food Nation: The Dark Side of the All-American Meal
# Let the Right One In
# Fifty Shades of Grey
# Saturday
# Suite Française
# Clockwork Prince
# Matched
# Flow Down Like Silver: Hypatia of Alexandria
# The Year of the Flood
# The Wise Man's Fear
# High in School
# The Girl on the Train
# Odd Thomas
# The Bookseller of Kabul
# Stiff: The Curious Lives of Human Cadavers
# Sex, Drugs, and Cocoa Puffs: A Low Culture Manifesto
# A Discovery of Witches
# Team of Rivals: The Political Genius of Abraham Lincoln
# If I Stay
# Possession of My Soul
# Snow
# A Great and Terrible Beauty
# Allegiant
# Under the Dome
# Dear John
# Last Sacrifice
# page 2 is done!

# %% [markdown]
# # Scrape Flixable Netflix Movies

# %%
page_iterations = list(range(1,100))
all_movies = []

for iteration_count in page_iterations:

    page = requests.get(f'https://flixable.com/genre/movies/?min-rating=0&min-year=1920&max-year=2020&order=date&page={iteration_count}')
    soup = BeautifulSoup(page.content, 'html.parser')
    table = soup.find_all('div', attrs={'class': 'col-sm-6 col-lg-3 mb-3'})

    for entry in table:
        try:
            href = entry.find('a', attrs={'class':'poster-link'})['href']
            page2 = requests.get(f'https://flixable.com{href}')
            soup2 = BeautifulSoup(page2.content, 'html.parser')

            #title
            title = soup2.find('h1', attrs={'class':'mb-3'}).get_text().strip()
            #image
            image = soup2.find('img', attrs={'class':'poster mb-4'})['src']
            #year
            year = soup2.find('span', attrs={'class':'mr-2'}).get_text()

            row = soup2.find('div', attrs={'class':'mb-2'})

            movie_traits = row.find_all('span')
            # release year
            release_year = movie_traits[0].get_text()
            # rating
            rating = movie_traits[1].get_text()
            # runtime
            runtime = movie_traits[2].get_text()

            movie_box = soup2.find('div', attrs={'class':'col-md-8'})
            # movie plot
            plot = movie_box.find('div', attrs={'class':'mb-3'}).get_text().strip()
            # movie genres
            genres = movie_box.find_all('div', attrs={'class':'mb-2'})[1].get_text()
            movie_genres = genres.replace('Genres:','').replace(',','').replace('Movies','').replace('&','').strip().split()

            #add to dictionary
            full_movie_entry = {'title':title, 'image':image, 'year':year, 
                                'release_year':release_year, 'rating':rating, 'runtime':runtime,
                                'plot':plot, 'genres':movie_genres}

            all_movies.append(full_movie_entry)
            print(f'{title} is done')
        except:
            pass

f = open("movie.csv", "w")
writer = csv.DictWriter(f, fieldnames=['title', 'image', 'year', 'release_year', 'rating', 'runtime', 'plot', 'genres'])
writer.writeheader()
writer.writerows(all_movies)
f.close()
# Out:
# A Ghost Story is done
# Live Twice, Love Once is done
# The Tourist is done
# All the Freckles in the World is done
# Deewangee is done
# Ferris Bueller's Day Off is done
# Half Girlfriend is done
# 21 is done
# A Cinderella Story is done
# Alpha and Omega: The Legend of the Saw Tooth Cave is done
# American Beauty is done
# Arthur Christmas is done
# Aruna & Her Palate is done
# As Good as It Gets is done
# Bad Grandpa .5 is done
# Breaking the Bank is done
# Catch Me If You Can is done
# Center Stage is done
# Charlie and the Chocolate Factory is done
# Chasing Amy is done
# Chitty Chitty Bang Bang is done
# Chloe is done
# City of God is done
# Click is done
# Cloverfield is done
# Coach Carter is done
# Dinner for Schmucks is done
# Donnie Brasco is done
# Dragonheart is done
# Dragonheart 3: The Sorcerer is done
# Dragonheart: A New Beginning is done
# Event Horizon is done
# Fall Girls is done
# Final Destination is done
# Final Destination 2 is done
# Final Destination 3 is done
# Free Willy is done
# Friday the 13th is done
# Garfield Gets Real is done
# Garfield's Fun Fest is done
# Garfield's Pet Force is done
# Ghost Rider is done
# Ghost Stories is done
# Godzilla is done
# Hairspray is done
# Harold & Kumar Go to White Castle is done
# Hitch is done
# Hunt to Kill is done
# Inception is done
# Instructions Not Included is done
# Jeff Dunham: Unhinged in Hollywood is done
# Jimmy Neutron: Boy Genius is done
# Julie & Julia is done
# Kate & Leopold is done
# Kill Bill: Vol. 1 is done
# Kill Bill: Vol. 2 is done
# Kingpin is done
# Kiss the Girls is done
# La Bamba is done
# Legend of the Guardians: The Owls of Ga'Hoole is done
# Luccas Neto in: Children's Day is done
# Magnolia is done
# Mandi is done
# Mansfield Park is done
# Monster-in-Law is done
# Moon is done
# My Girl is done
# New York Minute is done
# Pan's Labyrinth is done
# Paranormal Activity is done
# Patriot Games is done
# Philadelphia is done
# Pokémon the Movie: Power of Us is done
# Posesif is done
# Resident Evil: Afterlife is done
# Riot is done
# Road Trip: Beer Pong is done
# Scary Movie is done
# Seal Team Six: The Raid on Osama Bin Laden is done
# Siren is done
# Sliver is done
# Snow Day is done
# Strictly Ballroom is done
# Stuart Little is done
# Stuart Little 2 is done
# Sweeney Todd: The Demon Barber of Fleet Street is done
# Teenage Mutant Ninja Turtles II: The Secret of the Ooze is done
# Teenage Mutant Ninja Turtles: The Movie is done
# Terminator 3: Rise of the Machines is done
# Terminator Salvation is done
# The Amityville Horror is done
# The Craft is done
# The Crying Game is done
# The Dukes of Hazzard is done
# The Dukes of Hazzard: The Beginning is done
# The Final Destination is done
# The Invention of Lying is done
# The Lord of the Rings: The Return of the King is done
# The Lord of the Rings: The Two Towers is done
# The Mask of Zorro is done
# The Naked Gun 2 1/2: The Smell of Fear is done
# The Naked Gun: From the Files of Police Squad! is done
# The Natural is done
# The Original Kings of Comedy is done
# The Peacemaker is done
# The Ring is done
# The Talented Mr. Ripley is done
# Tremors is done
# Tremors 2: Aftershocks is done
# Tremors 3: Back to Perfection is done
# Tremors 4: The Legend Begins is done
# Tremors 5:  Bloodline is done
# True Grit is done
# Up in the Air is done
# What Lies Beneath is done
# Wild Wild West is done
# Willy Wonka & the Chocolate Factory is done
# Wyatt Earp is done
# Yes Man is done
# 3 Deewarein is done
# Aarakshan is done
# Aaviri is done
# Adrishya is done
# Ahista Ahista is done
# Albert Pinto Ko Gussa Kyun Aata Hai? is done
# Amar Akbar Anthony is done
# Anwar is done
# Barah Aana is done
# Bawarchi is done
# Bazaar is done
# Benchwarmers 2: Breaking Balls is done
# Bhagam Bhag is done
# Bhoot is done
# Bobby is done
# Carrie is done
# Chal Mere Bhai is done
# Child's Play is done
# Chupke Chupke is done
# Deadline: Sirf 24 Ghante is done
# Dhamaal is done
# Die Another Day is done
# Don is done
# Encounter: The Killing is done
# Ghayal is done
# Ghulam-E-Musthafa is done
# Gol Maal is done
# GoldenEye is done
# Golmaal: Fun Unlimited is done
# Heartbreakers is done
# Hera Pheri is done
# How High 2 is done
# Jaan-E-Mann: Let's Fall in Love... Again is done
# Jail is done
# Jis Desh Men Ganga Behti Hai is done
# John Day is done
# Judwaa is done
# Kaalia is done
# Katha is done
# Khubsoorat is done
# Koshish is done
# Kuldip Patwal: I Didn't Do It! is done
# Maine Pyaar Kyun Kiya is done
# Masoom is done
# Mujhse Shaadi Karogi is done
# Namak Halaal is done
# Phamous is done
# Phullu is done
# Rajnigandha is done
# Ram Teri Ganga Maili is done
# Ramji Londonwaley is done
# Red Dawn is done
# Road to Sangam is done
# Saath Saath is done
# Sadma is done
# Sangam is done
# Satte Pe Satta is done
# Shiva is done
# Swami is done
# The Dark Side of Life: Mumbai City is done
# The Great Gambler is done
# The World Is Not Enough is done
# Tomorrow Never Dies is done
# Traffic Signal is done
# Trikal (Past, Present, Future) is done
# Union Leader is done
# Veerey Ki Wedding is done
# Vodka Diaries is done
# Zed Plus is done
# Lawless is done
# Hot Gimmick: Girl Meets Boy is done
# Blitz Patrollie is done
# El Pepe, a Supreme Life is done
# The Secret Life of Pets 2 is done
# The Vendor is done
# The App is done
# Doom: Annihilation is done
# Fireworks is done
# Grand-Daddy Day Care is done
# Jarhead: Law of Return is done
# MFKZ is done
# Sweetheart is done
# Como caído del cielo is done
# John Mulaney & The Sack Lunch Bunch is done
# Jacob's Ladder is done
# Back of the Net is done
# Lost in London is done
# Being Mrs Elliot is done
# Falz Experience is done
# Iyore is done
# The First Lady is done
# The Two Popes is done
# After the Raid is done
# Ronny Chieng: Asian Comedian Destroys America! is done
# Burlesque is done
# Sincerely Yours, Dhaka is done
# The Danish Girl is done
# A Family Man is done
# Bangistan is done
# Dil Chahta Hai is done
# Dil Dhadakne Do is done
# Don is done
# Don 2 is done
# Fukrey is done
# Game is done
# Holy Expectations is done
# Honeymoon Travels Pvt. Ltd. is done
# Hope: One in a Billion is done
# Isoken is done
# Karthik Calling Karthik is done
# Lakshya is done
# Luck by Chance is done
# Potato Potahto is done
# Rock On!! is done
# Scooby-Doo on Zombie Island is done
# Talaash is done
# Tom and Jerry: The Magic Ring is done
# Underdogs is done
# Zindagi Na Milegi Dobara is done
# 6 Underground is done
# A Trip to Jamaica is done
# My Wife and I is done
# Okafor's Law is done
# Seven and a half dates is done
# Silent Hill: Revelation is done
# The 9th Precinct is done
# Zero Hour is done
# Jack Whitehall: Christmas with My Father is done
# The Sky Is Pink is done
# Good and Prosperous is done
# Michelle Wolf: Joke Show is done
# A Family Reunion Christmas is done
# It Comes at Night is done
# From Paris with Love is done
# Saaho is done
# Imagine That is done
# Nothing to Lose 2 is done
# Banana Island Ghost is done
# Celebrity Marriage is done
# Marriage Story is done
# No Game No Life: Zero is done
# Slow Country is done
# Spirit Riding Free: Spirit of Christmas is done
# THE RUM DIARY is done
# Wives on Strike is done
# Wives on Strike: The Revolution is done
# A Christmas Prince: The Royal Baby is done
# The Irishman: In Conversation is done
# Let's Dance is done
# The First Temptation of Christ is done
# Tiffany Haddish: Black Mitzvah is done
# War on Everyone is done
# Wish Man is done
# A Cinderella Story: Christmas Wish is done
# A Night at the Roxbury is done
# Austin Powers in Goldmember is done
# Austin Powers: International Man of Mystery is done
# Austin Powers: The Spy Who Shagged Me is done
# Baby Dolls is done
# Cut Bank is done
# Dead Kids is done
# High End Yaariyan is done
# Hustle & Flow is done
# Iron Fists and Kung-Fu Kicks is done
# Jindua is done
# Lakeeran is done
# Mahi NRI is done
# Martin Lawrence Live: Runteldat is done
# Primal Fear is done
# Qismat is done
# Searching for Sugar Man is done
# Sweet Virginia is done
# Tee Shot: Ariya Jutanugarn is done
# The Adventures of Sharkboy and Lavagirl is done
# The Departed is done
# The Tribes of Palos Verdes is done
# Thug Life is done
# Wandering Stars is done
# Why Me? is done
# Guatemala: Heart of the Mayan World is done
# The Zoya Factor is done
# Atlantics is done
# Crazy people is done
# I Lost My Body is done
# Kalushi: The Story of Solomon Mahlangu is done
# Lagos Real Fake Life is done
# Payday is done
# The Accidental Spy is done
# The Island is done
# Holiday Rush is done
# The Score is done
# Defiance is done
# Evvarikee Cheppoddu is done
# Little Singham: Mahabali is done
# The Body Remembers When the World Broke Open is done
# The Irishman is done
# Mike Birbiglia: The New One is done
# Super Monsters Save Christmas is done
# True: Winter Wishes is done
# Pranaam is done
# What the F* Is Going On? is done
# Awake is done
# Popeye is done
# Shot Caller is done
# Charlotte's Web is done
# End of Watch is done
# Hamburger Hill is done
# The Time Machine is done
# Brother is done
# Girls und Panzer der Film is done
# Mike Birbiglia: What I Should Have Said Was Nothing: Tales from My Secret Public Journal is done
# Shelby American is done
# K-19: The Widowmaker is done
# The Knight Before Christmas is done
# Adore is done
# Be Somebody is done
# Beavis and Butt-head Do America is done
# Bebe's Kids is done
# Bikram: Yogi, Guru, Predator is done
# Black Snake Moan is done
# Carriers is done
# Dorasaani is done
# Dream/Killer is done
# Evolution is done
# Eye for an Eye is done
# Hot Rod is done
# It Takes Two is done
# Lorena, Light-Footed Woman is done
# Love, Rosie is done
# Mallesham is done
# Once Upon a Time in the West is done
# She's Out of My League is done
# Superstar is done
# The Adventures of Tintin is done
# The Devil Inside is done
# The First Wives Club is done
# The Gift is done
# The Goods: Live Hard, Sell Hard is done
# The Longest Yard is done
# The Love Guru is done
# The Rainmaker is done
# What's Eating Gilbert Grape is done
# World Trade Center is done
# Young Adult is done
# Yours, Mine and Ours is done
# Zodiac is done
# Iliza Shlesinger: Unveiled is done
# Drive is done
# Iron Sky: The Coming Race is done
# Jeff Dunham: All Over the Map is done
# Suffragette is done
# The Green Inferno is done
# Earthquake Bird is done
# El sendero de la anaconda is done
# GO! The Unforgettable Party is done
# Guna 369 is done
# House Arrest is done
# K-on! the movie is done
# Klaus is done
# SunGanges is done
# The 24 Hour War is done
# The Garden of Words is done
# Clarence Clemons: Who Do I Think I Am? is done
# Fadily Camara : La plus drôle de tes copines is done
# Jeff Garlin: Our Man In Chicago is done
# A Single Man is done
# Submission is done
# To Be of Service is done
# Hit & Run is done
# Let It Snow is done
# Paradise Beach is done
# U Turn is done
# Burning Cane is done
# Shadow is done
# Luccas Neto in: Summer Camp is done
# Seth Meyers: Lobby Baby is done
# The Lovers is done
# Tune in for Love is done
# Undercover Brother 2 is done
# District 9 is done
# Kicking and Screaming is done
# Minimalism: A Documentary About the Important Things is done
# Oththa Seruppu Size 7 is done
# Takers is done
# 100 Things to do Before High School is done
# A Fairly Odd Summer is done
# Big Time Movie is done
# Don't Be Afraid of the Dark is done
# Escape from Mr. Lemoncello’s Library is done
# Hey Arnold! The Jungle Movie is done
# Jinxed is done
# LEGENDS OF THE HIDDEN TEMPLE is done
# Liar, Liar, Vampire is done
# Shark Night is done
# The Boy Who Cried Werewolf is done
# The Massively Mixed-Up Middle School Mystery is done
# A Remarkable Tale is done
# American Son is done
# Anger Management is done
# Apache Warrior is done
# Christmas in the Heartland is done
# Christmas Survival is done
# Drive is done
# Euphoria is done
# Fire in Paradise is done
# Grease is done
# Holiday in the Wild is done
# Holly Star is done
# How to Be a Latin Lover is done
# Legion is done
# Like Water for Chocolate is done
# Mad Money is done
# Monster House is done
# Nacho Libre is done
# Paid in Full is done
# Revolutionary Road is done
# Rosemary's Baby is done
# Rounders is done
# Santa Girl is done
# Sling Blade is done
# Spider-Man 3 is done
# Spitfire: The Plane that Saved the World is done
# Step Brothers is done
# The Christmas Candle is done
# The Great Raid is done
# The House of Flowers Presents: The Funeral is done
# The King is done
# The Man Without Gravity is done
# The Matrix is done
# The Matrix Reloaded is done
# The Matrix Revolutions is done
# The Old Thieves: The Legend of Artegios is done
# The Tuxedo is done
# True: Grabbleapple Harvest is done
# Vantage Point is done
# Zoé: Panoramas is done
# Zombieland is done
# Grego Rossello: Disculpe las molestias is done
# Mehandi Circus is done
# Arsenio Hall: Smart & Classy is done
# The Road to El Camino: Behind the Scenes of El Camino: A Breaking Bad Movie is done
# A 3 Minute Hug is done
# Little Miss Sumo is done
# The Last Whistle is done
# A Tale of Love and Darkness is done
# Assimilate is done
# Consequences is done
# Dolemite Is My Name is done
# It Takes a Lunatic is done
# My Next Guest with David Letterman and Shah Rukh Khan is done
# Rattlesnake is done
# The Awakening of Motti Wolkenbruch is done
# Echo in the Canyon is done
# Revenge of the Pontianak is done
# American Heist is done
# Dancing with the Birds is done
# Master Z: The Ip Man Legacy is done
# Hunter's Prayer is done
# I'll See You in My Dreams is done
# Jenny Slate: Stage Fright is done
# The Texas Chainsaw Massacre is done
# Tracers is done
# يوم الدين is done
# Free Fire is done
# Little Singham: Kaal Ki Tabaahi is done
# Men in Black is done
# Moms at War is done
# The Command is done
# 10 Days in Sun City is done
# 93 Days is done
# Eli is done
# In My Country is done
# Love, Surreal and Odd is done
# New Money is done
# Seventeen is done
# Tatu is done
# Tell Me Who I Am is done
# The Laundromat is done
# Up North is done
# Upstarts is done
# Verses of Love 2 is done
# The Karate Kid is done
# Ghosts of Sugar Land is done
# League of Legends Origins is done
# Park Na-rae: Glamour Warning is done
# Sinister 2 is done
# The Game Changers is done
# Dark Crimes is done
# Homeland is done
# Martin Matte: La vie, la mort...eh la la..! is done
# Street Flow is done
# Bygones Be Bygones is done
# El Camino: A Breaking Bad Movie is done
# Fractured is done
# The Bling Lagosians is done
# The Forest of Love is done
# The Influence is done
# GEN HOSHINO STADIUM TOUR “POP VIRUS” is done
# After is done
# Home Is Where the Killer Is is done
# Deon Cole: Cole Hearted is done
# The Spooky Tale of Captain Underpants Hack-a-ween is done
# The Water Diviner is done
# Love for Sale is done
# Noblemen is done
# A Plastic Ocean is done
# Brother in Love is done
# In the Tall Grass is done
# Kids on the Block is done
# Super Monsters: Vida's First Halloween is done
# Forks Over Knives is done
# Ready to Mingle is done
# Salam - The First ****** Nobel Laureate is done
# 300 Miles to Heaven is done
# A.M.I. is done
# Along Came a Spider is done
# Alpha and Omega 2: A Howl-iday Adventure is done
# Bad Boys is done
# Bad Boys II is done
# Blow is done
# Candyman is done
# Charlie's Angels is done
# Charlie's Angels: Full Throttle is done
# Crash is done
# Earth to Echo is done
# Escape from the "Liberty" Cinema is done
# First Kiss is done
# Good Burger is done
# Good Luck Chuck is done
# Hotel Pacific is done
# House of the Witch is done
# Jealousy and medicine is done
# Limitless is done
# Little Baby Bum: Go Buster is done
# Medium is done
# Men in Black II is done
# Nikki Glaser: Bangin’ is done
# Raging Bull is done
# Rugrats in Paris: The Movie is done
# Scream 2 is done
# Sin City is done
# Sinister Circle is done
# The Bounty Hunter is done
# The Cruise is done
# The Figurine (Araromire) is done
# The lynx is done
# The Pursuit of Happyness is done
# The Rugrats Movie is done
# The spiral is done
# The Squid and the Whale is done
# Trainspotting is done
# Walking Out is done
# Weather forecast is done
# Westerplatte Resists is done
# Mo Gilligan: Momentum is done
# Cultivating the Seas: History and Future of the Full-Cycle Cultured Kindai Tuna is done
# Domino is done
# TUNA GIRL is done
# Deliha 2 is done
# In the Shadow of the Moon is done
# Sturgill Simpson Presents Sound & Fury is done
# Malaal is done
# The Grandmaster is done
# Birders is done
# Furie is done
# Leap! is done
# Oh! Baby (Malayalam) is done
# Oh! Baby (Tamil) is done
# USS Indianapolis: Men of Courage is done
# Inside Man: Most Wanted is done
# Jeff Dunham: Beside Himself is done
# Manmadhudu 2 is done
# Under the Eiffel Tower is done
# Do Paise Ki Dhoop Chaar Aane Ki Baarish is done
# King of Boys is done
# Merry Men: The Real Yoruba Demons is done
# Sarah's Key is done
# The Wedding Party 2: Destination Dubai is done
# Between Two Ferns: The Movie is done
# Daddy Issues is done
# Travel Mates 2 is done
# True: Tricky Treat Day is done
# Kabir Singh is done
# Océans is done
# Come and Find Me is done
# A Haunting at Silver Falls: The Return is done
# Avengement is done
# Clive Davis: The Soundtrack of Our Lives is done
# Five Elements Ninjas is done
# Sebastian Maniscalco: What's Wrong with People? is done
# I Am Wrath is done
# Los Tigres del Norte at Folsom Prison is done
# Steal a Pencil for Me is done
# The Outsider is done
# Oh! Baby is done
# The Crystal Calls Making the Dark Crystal: Age of Resistance is done
# American Warfighter is done
# Deviant Love is done
# Head Count is done
# Hello, Privilege. It's Me, Chelsea is done
# Locked on You is done
# Shanghai Fortress is done
# Tall Girl is done
# Time Trap is done
# Turbo is done
# Bill Burr: Paper Tiger is done
# Eat Pray Love is done
# Evelyn is done
# Our Godfather is done
# Norm of the North: King Sized Adventure is done
# Article 15 is done
# Care of Kancharapalem is done
# Ee Nagaraniki Emaindi is done
# Kill Me If You Dare is done
# American Factory: A Conversation with the Obamas is done
# Saawan is done
# The Heretics is done
# The World We Make is done
# Watchman is done
# 68 Kill is done
# American Psycho is done
# Elena is done
# First Kill is done
# For the Birds is done
# Igor is done
# Mokalik (Mechanic) is done
# October 1 is done
# Olmo & the Seagull is done
# Phone Swap is done
# Rachel Getting Married is done
# Spookley the Square Pumpkin is done
# Stripes is done
# The Bridge is done
# The CEO is done
# The Last Exorcism is done
# The Saint is done
# The Taking of Pelham 123 is done
# Uncle Naji in UAE is done
# Used Goods is done
# You Don't Mess with the Zohan is done
# Back to School is done
# Feo pero sabroso is done
# Mi amigo Alexis is done
# Unbridled is done
# Expo is done
# Falling Inn Love is done
# Kardec is done
# Starred Up is done
# Travis Scott: Look Mom I Can Fly is done
# Dave Chappelle: Sticks & Stones is done
# One Last Thing is done
# Drink Drank Drunk is done
# Fanatic is done
# Kaake Da Viyah is done
# Marriage Palace is done
# Mayday Life is done
# Saavat is done
# The Congress is done
# American Factory is done
# Game Over (Hindi Version) is done
# Game Over (Tamil Version) is done
# Game Over (Telugu Version) is done
# The Girl Allergic to Wi-Fi is done
# Gangs of New York is done
# Our Planet - Behind The Scenes is done
# Simon Amstell: Set Free is done
# For Love or Money is done
# Invader Zim: Enter the Florpus is done
# Selfless is done
# Sextuplets is done
# Super Monsters Back to School is done
# The Little Switzerland is done
# Chhota Bheem Kungfu Dhamaka is done
# Whindersson Nunes: Adult is done
# Uyare is done
# 90 ML is done
# Calum von Moger: Unbroken is done
# Hasta los dientes is done
# Woodstock is done
# Colin Quinn: Red State Blue State is done
# Jaoon Kahan Bata Ae Dil is done
# Rocko's Modern Life: Static Cling is done
# Westside vs. the World is done
# Judy Moody and the Not Bummer Summer is done
# Roll Red Roll is done
# St. Agatha is done
# Badla is done
# The Pursuit is done
# Theo Von: No Offense is done
# Crazy Beautiful You is done
# I'm Brent Morin is done
# Jim Jefferies : BARE is done
# Professor Mack is done
# Screwball is done
# Sebastian Maniscalco: Why Would You Do That is done
# Alarmoty in the Land of Fire is done
# Detention Letter is done
# Enter the Anime is done
# No One Will Ever Know is done
# Misfit is done
# For Greater Glory is done
# Léa & I is done
# Otherhood is done
# Uriyadi 2 is done
# 3 Idiots is done
# Are We Done Yet? is done
# Boyka: Undisputed is done
# Clash of the Titans is done
# Darna Mana Hai is done
# Ek Hasina Thi is done
# Ferrari Ki Sawaari is done
# Horns is done
# Jupiter Ascending is done
# Last Knights is done
# Manu is done
# MI-5 is done
# Panic Room is done
# Running Out Of Time is done
# Something's Gotta Give is done
# To Wong Foo, Thanks for Everything! Julie Newmar is done
# Wazir is done
# White Chamber is done
# The Red Sea Diving Resort is done
# All Good Ones Get Away is done
# American Hangman is done
# Whitney Cummings: Can I Touch It? is done
# Mission of Honor is done
# The Croods is done
# 1st Summoning is done
# Boi is done
# Eerie is done
# Girls With Balls is done
# Guy Martin: Last Flight of the Vulcan Bomber is done
# The Exception is done
# The Son is done
# The Great Hack is done
# The Competition is done
# Inglourious Basterds is done
# Unfinished Song is done
# Bewafaa is done
# Connected is done
# D.L. Hughley: Contrarian is done
# Demetri Martin: The Overthinker is done
# The Beast Stalker is done
# The Midas Touch is done
# The Twins Effect II is done
# Twins Mission is done
# May You Prosper is done
# ¡Ay, mi madre! is done
# Iron Cowboy: The Story of the 50.50.50 is done
# Secret Obsession is done
# Short Term 12 is done
# Mauli is done
# Bogda is done
# Frankenstein’s Monster’s Monster, Frankenstein is done
# Jack of all Trades is done
# The Princess and the Frog is done
# Love Shot is done
# Plaire, aimer et courir vite is done
# 4L is done
# Black & Privileged: Volume 1 is done
# Cities of Last Things is done
# Kidnapping Stella is done
# Point Blank is done
# Smart People is done
# The Milk System is done
# Little Singham Bandarpur Mein Hu Ha Hu is done
# Parchís: the Documentary is done
# Aziz Ansari: RIGHT NOW is done
# Mary Poppins Returns is done
# The Iron Lady is done
# River, el más grande siempre is done
# Cristina is done
# Skiptrace is done
# Katherine Ryan: Glitter Room is done
# Kill the Irishman is done
# Little Monsters is done
# Mean Dreams is done
# NOVA: Bird Brain is done
# NOVA: Black Hole Apocalypse is done
# NOVA: Building Chernobyl's MegaTomb is done
# NOVA: Chinese Chariot Revealed is done
# NOVA: Day the Dinosaurs Died is done
# NOVA: Death Dive to Saturn is done
# NOVA: Decoding the Weather Machine is done
# NOVA: Eclipse Over America is done
# NOVA: Extreme Animal Weapons is done
# NOVA: First Face of America is done
# NOVA: Holocaust Escape Tunnel is done
# NOVA: Killer Floods is done
# NOVA: Killer Hurricanes is done
# NOVA: Killer Volcanoes is done
# NOVA: Poisoned Water is done
# NOVA: Prediction by the Numbers is done
# NOVA: Secrets of the Shining Knight is done
# NOVA: Thai Cave Rescue is done
# NOVA: The Impossible Flight is done
# Nova: Ultimate Mars Challenge is done
# Race to Witch Mountain is done
# Room on the Broom is done
# Scream 3 is done
# Shorts is done
# Swiped is done
# Tayo the Little Bus Movie: Mission Ace is done
# The Accountant of Auschwitz is done
# The Forbidden Kingdom is done
# War Against Women is done
# Inhuman Kiss is done
# Romeo Akbar Walter is done
# Pierre Jackson is done
# Super Deluxe is done
# 20th Century Women is done
# El testigo is done
# La Leyenda del Diamante is done
# ANIMA is done
# Daniel Sosa: Maleducado is done
# Hikaru Utada Laughter in the Dark Tour 2018 is done
# Kahaani is done
# Spider-Man: Into the Spider-Verse is done
# The Golem is done
# Unbroken is done
# Mike Epps: Only One Mike is done
# Recall is done
# Tottaa Pataaka Item Maal is done
# The Long Goodbye: The Kara Tippetts Story is done
# Salem: His Sister's Father is done
# Triple Threat is done
# Blood Will Tell is done
# EVANGELION: DEATH (TRUE)² is done
# Good Luck is done
# The End of Evangelion is done
# An Upper Egyptian is done
# Bewildered Bolbol is done
# Rakkhosh is done
# Reaction is done
# The Chord is done
# The Player is done
# The Wolf's Call is done
# Three-Quarters Decent is done
# Unruly Friends is done
# Beats is done
# Memory Games is done
# Running for Grace is done
# The Edge of Democracy is done
# VS. is done
# Adam Devine: Best Time of Our Lives is done
# Antariksha Ke Rakhwale is done
# Big Kill is done
# Bob Lazar: Area 51 & Flying Saucers is done
# Dragonkala Ka Rahasya is done
# Samudri Lootere is done
# Super Bheem Bana Vajraveer is done
# Cop Car is done
# Right Here Right Now is done
# 3 Seconds Divorce is done
# Life Overtakes Me is done
# Luckee is done
# Monopoly (The Bank Of Luck) is done
# Pihu is done
# DJ Cinderella is done
# Murder Mystery is done
# Convict is done
# Flimflam is done
# Oprah Presents When They See Us Now is done
# Savage Raghda is done
# The 3rd Eye 2 is done
# The Ant's Scream is done
# The Cell is done
# The Right One is done
# Jo Koy: Comin' In Hot is done
# Rolling Thunder Revue: A Bob Dylan Story by Martin Scorsese is done
# Ralph Breaks the Internet: Wreck-It Ralph 2 is done
# Beneath the Leaves is done
# Berlin, I Love You is done
# Equilibrium is done
# Belmonte is done
# Elisa & Marcela is done
# I Am Mother is done
# Luka Chuppi is done
# Pachamama is done
# Rock My Heart is done
# Stree is done
# The Black Godfather is done
# A Perfect Man is done
# Alles ist gut is done
# Best Neighbors is done
# Cabin Fever is done
# Everybody Knows is done
# Farce is done
# Freezer's Campaign is done
# From Japan to Egypt is done
# Immoral Tales is done
# It's Okay, Buddy is done
# Ms. Mammy is done
# Sameer Abu Alneel is done
# Step Outside is done
# The Republic of Imbaba is done
# The Thief and the Imbecile is done
# A Silent Voice is done
# Dolphin Kick is done
# Dr. Seuss' The Grinch is done
# Jiro Dreams of Sushi is done
# Would You Rather is done
# Cosmos Laundromat: First Cycle is done
# Miranda Sings Live…Your Welcome is done
# Silent is done
# The Men Who Stare at Goats is done
# Krutant is done
# The Duel is done
# #Selfie is done
# #Selfie 69 is done
# 50/50 is done
# III Smoking Barrels is done
# Life in the Doghouse is done
# Love Is a Story is done
# Oh, Ramona! is done
# Prosecuting Evil: The Extraordinary World of Ben Ferencz is done
# Righteous Kill is done
# Satan & Adam is done
# Small Soldiers is done
# The Space Between Us is done
# Then Came You is done
# We Are Legends is done
# Always Be My Maybe is done
# C Kkompany is done
# Chopsticks is done
# Koi Aap Sa is done
# Krishna Cottage is done
# Mere Pyare Prime Minister is done
# P is done
# Pegasus is done
# Ragini MMS is done
# Ragini MMS 2 is done
# Shor In the City is done
# My Week with Marilyn is done
# Svaha: The Sixth Finger is done
# The One I Love is done
# Lifechanger is done
# The Nutcracker and the Four Realms is done
# After Porn Ends is done
# Rampant is done
# After Maria is done
# Joy is done
# Rim of the World is done
# The Perfection is done
# The Lonely Island Presents: The Unauthorized Bash Brothers Experience is done
# A Tale of Two Kitchens is done
# The Man Who Feels No Pain is done
# Moonlight is done
# Wanda Sykes: Not Normal is done
# Zero is done
# SGT. Will Gardner is done
# The Blackcoat's Daughter is done
# The Brawler is done
# Born in Gaza is done
# Born in Syria is done
# Dying to Tell is done
# First Impression is done
# Maria is done
# ReMastered: The Lion's Share is done
# Saverio Raimondo: Il Satiro Parlante is done
# See You Yesterday is done
# Good Sam is done
# Jonaki is done
# Kyo Kii... Main Jhuth Nahin Bolta is done
# Limitless is done
# LSD: Love, Sex Aur Dhokha is done
# Mission Istaanbul: Darr Ke Aagey Jeet Hai is done
# Once Upon a Time in Mumbai Dobaara! is done
# PATRICK (2019) is done
# Take Me Home Tonight is done
# 7 Din Mohabbat In is done
# All the Devil's Men is done
# Cake is done
# EMI: Liya Hai To Chukana Padega is done
# Hamid is done
# Kucch To Hai is done
# Kyaa Kool Hai Hum is done
# Kyaa Kool Hain Hum 3 is done
# Once Upon a Time in Mumbaai is done
# Shootout at Lokhandwala is done
# Backdraft 2 is done
# Killer Cove is done
# Still LAUGH-IN: The Stars Celebrate is done
# Weed the People is done
# Malibu Rescue is done
# Norm of the North: Keys to the Kingdom is done
# Merata: How Mum Decolonised the Screen is done
# Dry Martina is done
# Shéhérazade is done
# The Great Magician is done
# Bheemayan is done
# Chhota Bheem Aur Kaala Yodha is done
# Chhota Bheem Ka Romani Adventure is done
# Chhota Bheem Ka Troll Se Takkar is done
# In Family I Trust is done
# Wine Country is done
# Antar: Son of Shadad is done
# Bathtubs Over Broadway is done
# Gatao 2: Rise of the King is done
# Insidious is done
# Lion's Heart is done
# Regatta is done
# Tattah is done
# The Bulbul's Nest is done
# The Heat: A Kitchen (R)evolution is done
# Last Breath is done
# Like Arrows is done
# The Wandering Earth is done
# War Horse is done
# Death House is done
# All In My Family is done
# Despite Everything is done
# Extremely Wicked, Shockingly Evil and Vile is done
# It's Fine is done
# Jo Pil-ho: The Dawning Rage is done
# The Last Summer is done
# Hamza's Suitcase is done
# Her Only Choice is done
# John Carter is done
# Laatu is done
# Olympus Has Fallen is done
# American Experience: The Island Murder is done
# Dr. Seuss' The Cat in the Hat is done
# Familiye is done
# Hidden in Plain Sight is done
# John & Yoko: Above Us Only Sky is done
# Kia and Cosmos is done
# Kill Hitler! The Luck of the Devil is done
# Knock Down The House is done
# Le serment des Hitler is done
# Munafik 2 is done
# Robin Hood: The Rebellion is done
# Snowpiercer is done
# Sur Sapata is done
# Teenage Mutant Ninja Turtles is done
# Two Graves is done
# A Home with A View is done
# Anthony Jeselnik: Fire in the Maternity Ward is done
# Perfect Bid: The Contestant Who Knew Too Much is done
# Burning is done
# CRD is done
# Teen Aur Aadha is done
# American Honey is done
# Amar's Hands is done
# An Hour and a Half is done
# Kon-Tiki is done
# Loving is Losing is done
# Money Trap is done
# Njan Prakashan is done
# ReMastered: Devil at the Crossroads is done
# Season of the Witch is done
# The Sapphires is done
# A Mission in an Old Movie is done
# Aurora is done
# Goosebumps 2: Haunted Halloween is done
# Love Station is done
# Omar and Salma 3 is done
# Shattered Memories is done
# The Consul's Son is done
# The Ugly Truth is done
# Fireflies is done
# Furthest Witness is done
# Little Singham in London is done
# The Last Resort is done
# A Fortunate Man is done
# Grass Is Greener is done
# Paper Year is done
# Abdo Mota is done
# Brampton's Own is done
# Brené Brown: The Call to Courage is done
# I, Daniel Blake is done
# Music Teacher is done
# Roh's Beauty is done
# Someone Great is done
# The Mayo Clinic is done
# The Ruthless is done
# 30 Days of Luxury is done
# Because We're Heading Out is done
# My Dog is My Guide is done
# My Wife and My Wifey is done
# The Walls of the Moon is done
# Warda is done
# A Little Chaos is done
# Dabbe 6: The Return is done
# De Film van Dylan Haegens is done
# Franco Escamilla: Bienvenido al mundo is done
# HOMECOMING: A film by Beyoncé is done
# 21 & Over is done
# About Time is done
# Jonathan is done
# Super Monsters Furever Friends is done
# The Creative Brain is done
# Bollywood Calling is done
# Ek Khiladi Ek Haseena is done
# Generation Iron 3 is done
# Hazaaron Khwaishein Aisi is done
# Jhankaar Beats is done
# Mumbai Matinee is done
# Rainbow Jelly is done
# Shabd is done
# Shortcut Safari is done
# The New Romantic is done
# Antidote is done
# Thriller is done
# A Land Imagined is done
# Who Would You Take to a Deserted Island? is done
# Azhar is done
# Band Aid is done
# Buffalo Boys is done
# Dabbe 5: Zehr-i Cin is done
# Dabbe: The Possession is done
# Francesco De Carlo: Cose di Questo Mondo is done
# Horror Story is done
# The Perfect Date is done
# #Roxy is done
# Liss Pereira: Reteniendo líquidos is done
# The Silence is done
# Movie 43 is done
# The Basement is done
# Sarvam Thaala Mayam (Telugu Version) is done
# The Great Battle is done
# Petta (Telugu Version) is done
# Between Worlds is done
# Queen of the Desert is done
# Alien Warfare is done
# Backfire is done
# Lupt is done
# Petta is done
# Playing Hard is done
# The Spy Who Fell to Earth is done
# Unicorn Store is done
# 14 Blades is done
# Ricardo Quevedo: Los amargados somos más is done
# Suzzanna: Buried Alive is done
# Boy Bye is done
# Ek Ladki Ko Dekha Toh Aisa Laga is done
# Jagat is done
# Kevin Hart: Irresponsible is done
# 706 is done
# Across The Line is done
# American Masters: Ted Williams is done
# Arthur is done
# Hedgehogs is done
# I Am Maris is done
# Jesus: Countdown to Calvary is done
# Love O2O is done
# P.S. I Love You is done
# Pinky Memsaab is done
# Spy Kids is done
# Spy Kids 3: Game Over is done
# The Bye Bye Man is done
# The Legend of Michael Mishra is done
# The Trap is done
# The Trust is done
# The World's Most Wanted Animal is done
# Mercy Black is done
# The Burial of Kojo is done
# 15 August is done
# Bayonet is done
# The Bleeder is done
# The Highwaymen is done
# The Legend of Cocaine Island is done
# Tucker and Dale vs. Evil is done
# Wolves is done
# Danur: I Can See Ghosts is done
# Verses of Love is done
# Nate Bargatze: The Tennessee Kid is done
# Sei is done
# Superlopez is done
# I Don't Know How She Does It is done
# Oversize Cops is done
# Mirage is done
# ReMastered: The Miami Showband Massacre is done
# The Dirt is done
# The Rolling Stones: Olé Olé Olé! A Trip Across Latin America is done
# Antoine Griezmann: The Making of a Legend is done
# The Amazing Praybeyt Benjamin is done
# The Super Parental Guardians is done
# The Third Party is done
# The Unmarried Wife is done
# The Wedding Curse is done
# Vince and Kath and James is done
# A.X.L. is done
# Alexis Viera: A Story of Surviving is done
# Imago is done
# Amy Schumer Growing is done
# Social Animals is done
# Tinker' is done
# All About Nina is done
# 5 Flights Up is done
# A Separation is done
# Bombairiya is done
# Burn Out is done
# Chief Daddy is done
# Edoardo Ferrario: Temi Caldi is done
# G-Force is done
# Girl is done
# Jeff Dunham: Arguing with Myself is done
# Jeff Dunham: Controlled Chaos is done
# Jeff Dunham: Minding the Monsters is done
# Jeff Dunham's Very Special Christmas Special is done
# Kung Fu Hustle is done
# Late Life: The Chien-Ming Wang Story is done
# Paskal is done
# The Lives of Others is done
# The Student is done
# Twinsanity is done
# 12 ROUND GUN is done
# A Love Story is done
# Barcelona: A Love Untold is done
# Everything About Her is done
# Finally Found Someone is done
# Seven Sundays is done
# Triple Frontier is done
# Jimmy Carr: The Best of Ultimate Gold Greatest Hits is done
# Apollo 18 is done
# Blue Jasmine is done
# Hajwala 2: Mysterious Mission is done
# Juanita is done
# Lady J is done
# The Imaginarium of Doctor Parnassus is done
# The Jane Austen Book Club is done
# Walk. Ride. Rodeo. is done
# Doubt is done
# Nappily Ever After is done
# Sisterakas is done
# Starting Over Again is done
# That Thing Called Tadhana is done
# The Love Affair is done
# Bedtime Stories is done
# Caregiver is done
# Christopher Robin is done
# The Hard Way is done
# Everyday I Love You is done
# I Am is done
# Kid Kulafu is done
# My Only Mother is done
# No Other Woman is done
# The Dawn Wall is done
# Exit Strategy is done
# Middle School: The Worst Years of My Life is done
# Contract is done
# Dear Dad is done
# River's Edge is done
# Sarkar is done
# Sarkar is done
# Saving Mr. Banks is done
# Wakefield is done
# War Chhod Na Yaar is done
# Weapon of Choice is done
# Zubaan is done
# 2,215 is done
# An Interview with God is done
# BNK48: Girls Don't Cry is done
# Budapest is done
# Christmas in the Smokies is done
# Crouching Tiger, Hidden Dragon is done
# Dead in a Week (Or Your Money Back) is done
# Haunting on Fraternity Row is done
# Hulk Vs. is done
# Junebug is done
# Kilo Two Bravo is done
# Layer Cake is done
# Pants on Fire is done
# Paranormal Investigation is done
# Radio Rebel is done
# Room for Rent is done
# Sarvam Thaala Mayam (Tamil Version) is done
# The Boy Who Harnessed the Wind is done
# The Christmas Project is done
# The Incredible Story of the Giant Pear is done
# The Last Runway is done
# The Spiderwick Chronicles is done
# Tyson is done
# Your Son is done
# Billy Graham: An Extraordinary Journey is done
# Mine is done
# Quién te cantará is done
# The Rebound is done
# A Second Chance is done
# Beauty and the Bestie is done
# Bride For Rent is done
# Can't Help Falling in Love is done
# Evening Shadows is done
# Four Sisters and a Wedding is done
# Girl, Boy, Bakla, Tomboy is done
# It Takes a Man and a Woman is done
# My Ex & Whys is done
# Rise: Ini Kalilah is done
# She's Dating the Gangster is done
# The Breakup Playlist is done
# The Mistress is done
# The Only Mother To You All is done
# You Changed My Life is done
# You're My Boss is done
# Our Idiot Brother is done
# Zach Galifianakis: Live at the Purple Onion is done
# Blue Ruin is done
# Dolphin Tale 2 is done
# Life of An Outcast is done
# Ghost Pain is done
# Ghost Tears is done
# Ghost Whispers is done
# The Photographer Of Mauthausen is done
# Bert Kreischer: The Machine is done
# Firebrand is done
# Paddleton is done
# Paris Is Us is done
# Shonar Pahar is done
# The Prince is done
# The Unknown Known is done
# Trespass Against Us is done
# The Drug King is done
# The Intent 2: The Come Up is done
# Kevin James: Sweat the Small Stuff is done
# Transformer is done
# Postcards from London is done
# Spy Kids: All the Time in the World is done
# Genius is done
# Black Sea is done
# Studio 54 is done
# The Super is done
# Alone in Berlin is done
# Among Family is done
# Anchor and Hope is done
# Awe is done
# Ayana is done
# Behind the Curve is done
# Buddies is done
# Candyflip is done
# Chameli is done
# Deadly Scholars is done
# Fatso is done
# My Travel Buddy is done
# Neevevaro is done
# Never Heard is done
# Outlawed is done
# Pyaar Ke Side Effects is done
# Sur: The Melody of Life is done
# The Breaker Upperers is done
# The Detained is done
# Ugly Aur Pagli is done
# You're Everything To Me is done
# Yucatán is done
# Grass is done
# Ken Jeong: You Complete Me, Ho is done
# Merantau is done
# Period. End of Sentence. is done
# Ten Years is done
# We the Animals is done
# God Bless the Broken Road is done
# Don't Knock Twice is done
# High Flying Bird is done
# Incredibles 2 (Spanish Version) is done
# Kevin Hart's Guide to Black History is done
# ReMastered: The Two Killings of Sam Cooke is done
# The Tree of Blood is done
# Lez Bomb is done
# Di Renjie zhi Sidatianwang is done
# The Confirmation is done
# Ray Romano: Right Here, Around the Corner is done
# All Light Will End is done
# Await Further Instructions is done
# Manusangada is done
# Viking Destiny is done
# 14 Minutes from Earth is done
# Cats & Dogs: The Revenge of Kitty Galore is done
# Dear Ex is done
# E-Cigarettes: Miracle or Menace? is done
# Free Rein: Valentine's Day is done
# Guilty is done
# Have You Seen the Listers? is done
# Heal is done
# Lego DC Comics: Batman Be-Leaguered is done
# LEGO Marvel Super Heroes: Black Panther is done
# LEGO Marvel Super Heroes: Guardians of the Galaxy is done
# LEGO Ninjago: Masters of Spinjitzu: Day of the Departed is done
# Malicious is done
# Ninja Assassin is done
# Personal Shopper is done
# The Edge of Seventeen is done
# The Witch Files is done
# Truckbhar Swapna is done
# True: Happy Hearts Day is done
# Velvet Buzzsaw is done
# What Makes a Psychopath? is done
# Why Are We Getting So Fat? is done
# World's Weirdest Homes is done
# Agatha and the Truth of Murder is done
# Hantu Kak Limah is done
# I Dream Of Dance is done
# Love Off the Cuff is done
# The Gentleman Driver is done
# The Hundred-Foot Journey is done
# Maharaja: The Story of Ranjit Singh is done
# Sat Sri Akal is done
# Swiss Army Man is done
# The Incredibles 2 is done
# The Longshots is done
# Virsa is done
# Ant-Man and the Wasp is done
# Bhasmasur is done
# Gabriel "Fluffy" Iglesias: One Show Fits All is done
# High Society is done
# Up Among  The Stars is done
# Alt-Right: Age of Rage is done
# Habibie & Ainun is done
# Nathicharami is done
# Rudy Habibie is done
# Surga Yang Tak Dirindukan is done
# Surga Yang Tak Dirindukan 2 is done
# Goyo: The Boy General is done
# Animas is done
# Mi Obra Maestra is done
# Polar is done
# Hotel Transylvania 3: Summer Vacation is done
# Just Love is done
# Planet 51 is done
# Auschwitz: Blueprints of Genocide is done
# Close is done
# FYRE: The Greatest Party That Never Happened is done
# IO is done
# Lady-Like is done
# Old Lord Savanna is done
# Patria is done
# Soni is done
# Driven to Dance is done
# Skyline is done
# Abducted in Plain Sight is done
# Abdullah, The Final Witness is done
# Adhugo is done
# Chupan Chupai is done
# Deadly Switch is done
# Echcharikkai is done
# Only Mine is done
# Pandigai is done
# Pari is done
# Revenger is done
# Sebastian Maniscalco: Stay Hungry is done
# The Devil We Know is done
# The Doll is done
# The Doll 2 is done
# Invisible Essence: The Little Prince is done
# 13 Sins is done
# Baazaar is done
# The Fighter is done
# Becoming Jane is done
# He's Out There is done
# All of You is done
# ReMastered: Massacre at the Stadium is done
# Solo is done
# The Last Laugh is done
# GODZILLA The Planet Eater is done
# Next Enti? is done
# Solo: A Star Wars Story is done
# Solo: A Star Wars Story (Spanish Version) is done
# The Monster is done
# Catwalk: Tales from the Cat Show Circuit is done
# Komola Rocket is done
# Pahuna is done
# 3 Heroines is done
# 5 Cowok Jagoan is done
# Chaotic Love Poems is done
# Love You... Love You Not is done
# Mara is done
# Nang Nak is done
# Soekarno is done
# And Breathe Normally is done
# El Potro: Unstoppable is done
# Lionheart is done
# Occupation is done
# Pope Francis: A Man of His Word is done
# Monty Python and the Holy Grail is done
# A Perfect Ending is done
# Babel is done
# Back to the 90s is done
# Hell or High Water is done
# Indiana Jones and the Kingdom of the Crystal Skull is done
# Indiana Jones and the Last Crusade is done
# Indiana Jones and the Raiders of the Lost Ark is done
# Indiana Jones and the Temple of Doom is done
# Jersey Boys is done
# Krystal is done
# Merku Thodarchi Malai is done
# Moshe Kasher: Live in Oakland is done
# Pokémon the Movie: I Choose You! is done
# Puriyatha Puthir is done
# Taramani is done
# The Boy in the Striped Pajamas is done
# Trash is done
# Whitney Cummings: Money Shot is done
# Bill Hicks: One Night Stand is done
# Bill Hicks: Reflections is done
# Bill Hicks: Relentless is done
# Bill Hicks: Revelations is done
# Bill Hicks: Sane Man is done
# Gina Yashere: Laughing to America is done
# Gina Yashere: Skinny B*tch is done
# Mexicanos de Bronce is done
# Sam Kinison: Breaking the Rules is done
# Sam Kinison: Family Entertainment Hour is done
# Sam Kinison: Live in Vegas is done
# Sam Kinison: The Scream Continues is done
# Secrets in the Hot Spring is done
# Taylor Swift reputation Stadium Tour is done
# The Bill Murray Stories: Life Lessons Learned From a Mythical Man is done
# The Seven Deadly Sins the Movie: Prisoners of the Sky is done
# Tim Allen: Men Are Pigs is done
# Tim Allen: ReWires America is done
# Tim Minchin And The Heritage Orchestra Live is done
# Tim Minchin: So F**king Rock is done
# Todd Glass: Stand-Up Special is done
# Tom Papa Live in New York City is done
# After Porn Ends 3 is done
# The Autopsy of Jane Doe is done
# A Twelve Year Night is done
# Black Mirror: Bandersnatch is done
# Life Ki Toh Lag Gayi is done
# Oasis: Supersonic is done
# Rehmataan is done
# The Birth Reborn 3 is done
# When Angels Sleep is done
# At First Light is done
# Avengers: Infinity War is done
# Backtrack is done
# The Little Hours is done
# I Am Vengeance is done
# Mr. Church is done
# Bad Seeds is done
# Bird Box is done
# Struggle: The Life and Lost Art of Szukalski is done
# The Last Hangover is done
# 23:59 is done
# Aggretsuko: We Wish You a Metal Christmas is done
# Imperfect is done
# Lang Tong is done
# Miss J Contemplates Her Choice is done
# Ascharyachakit! is done
# The Humanity Bureau is done
# Lilli is done
# Prince of Peoria: A Christmas Moose Miracle is done
# Skin Trade is done
# American Circumcision is done
# Andhadhun is done
# Dragons: Dawn of the Dragon Racers is done
# Kill the Messenger is done
# Maps to the Stars is done
# One Day is done
# Springsteen on Broadway is done
# The Theory of Everything is done
# F.R.E.D.I. is done
# Kita Kita is done
# Once in a Lifetime Sessions with George Ezra is done
# Once in a Lifetime Sessions with Kasabian is done
# Once in a Lifetime Sessions with OneRepublic is done
# Once in a Lifetime Sessions with Snow Patrol is done
# Sad Hill Unearthed is done
# The Bad Education Movie is done
# Vanjagar Ulagam is done
# ROMA is done
# Samson is done
# Out of Many, One is done
# Standoff is done
# Vir Das: Losing It is done
# Goldstone is done
# Susanne Bartsch: On Top is done
# Because of Soccer is done
# The Art of the Steal is done
# The Dancer is done
# The Gathering is done
# What's Up With Love? is done
# 5 Star Christmas is done
# Dumplin' is done
# Free Rein: The Twelve Neighs of Christmas is done
# Mowgli: Legend of the Jungle is done
# ReMastered: Who Killed Jam Master Jay? is done
# Super Monsters and the Wish Star is done
# The American Meme is done
# Yes or No is done
# Breath is done
# God's Not Dead: A Light in Darkness is done
# RUSSELL BRAND: RE:BIRTH is done
# The Cakemaker is done
# Silencer is done
# Teefa in Trouble is done
# The Lobster is done
# A Beautiful Life is done
# Accident is done
# Ayotzinapa, el paso de la tortuga is done
# Battle is done
# Blind Detective is done
# Bobby Robson: More Than a Manager is done
# Break Up 100 is done
# Chal Bhaag is done
# Crossroads: One Two Jaga is done
# Don't Go Breaking My Heart is done
# Don't Go Breaking My Heart 2 is done
# Faraar is done
# Helios is done
# Hellboy is done
# Line Walker is done
# Little Singham aur Kaal ka Mahajaal is done
# Look for a Star is done
# Oddbods: The Festive Menace is done
# Once a Gangster is done
# Power Paandi is done
# Roll With Me is done
# SDU: Sex Duties Unit is done
# Set Off is done
# Seven Pounds is done
# The Little Mermaid is done
# A Christmas Prince: The Royal Wedding is done
# Angela's Christmas is done
# El club de los insomnes is done
# Garuda in My Heart 2 is done
# Happy as Lazzaro is done
# Love is done
# Manto is done
# Rajma Chawal is done
# The World Is Yours is done
# Time Share is done
# Brotherhood of Blades II: The Infernal Battlefield is done
# Operation Red Sea is done
# Harold and Lillian: A Hollywood Love Story is done
# My Little Pony Friendship Is Magic: Best Gift Ever is done
# The Christmas Chronicles is done
# De Palma is done
# The Tribe is done
# Puppy Star Christmas is done
# Sabrina is done
# Target is done
# Trevor Noah: Son of Patricia is done
# The Pixar Story is done
# Cam is done
# Follow Me is done
# Nothing to Hide is done
# The Ballad of Buster Scruggs is done
# The Princess Switch is done
# Aalorukkam is done
# Christmas Wedding Planner is done
# Halkaa is done
# Mala Kahich Problem Nahi is done
# May the Devil Take You is done
# Muzaffarnagar Baaqi Hai is done
# Odu Raja Odu is done
# Only the Dead is done
# Pimpal is done
# Savita Damodar Paranjpe is done
# Shopkins: Chef Club is done
# Shopkins: Wild is done
# Shopkins: World Vacation is done
# The Crew is done
# The Giant is done
# BuyBust is done
# Loudon Wainwright III: Surviving Twin is done
# Green Room is done
# The Workshop is done
# All's Well, End's Well (2009) is done
# Gabriel and the Mountain is done
# Lommbock is done
# Outlaw King is done
# Hope Springs Eternal is done
# The Desert Bride is done
# The Sea of Trees is done
# Yes or No 2 is done
# Yes or No 2.5 is done
# Into the Forest is done
# Krisha is done
# Bucket List is done
# John Leguizamo's Latin History for Morons is done
# Hoodwinked Too! Hood vs. Evil is done
# Ana e Vitória is done
# ReMastered: Tricky Dick & The Man in Black is done
# The Holiday Calendar is done
# The Other Side of the Wind is done
# They’ll Love Me When I’m Dead is done
# A Wednesday is done
# Aagey Se Right is done
# Aamir is done
# ABCD 2 is done
# ABCD: Any Body Can Dance is done
# Arjun: The Warrior Prince is done
# Asees is done
# Barfi! is done
# Calico Critters: A Town of Dreams is done
# Calico Critters: The Treasure of Calico Village is done
# Chaar Sahibzaade is done
# Chance Pe Dance is done
# Christmas With A View is done
# Chup Chup Ke is done
# Dhan Dhana Dhan Goal is done
# Dhoondte Reh Jaoge is done
# Do Dooni Chaar is done
# Edge of Fear is done
# Edmilson Filho: Notas, Comedy about Relationships is done
# Filmworker is done
# Gaddar: the Traitor is done
# Ghanchakkar is done
# Grandmaster is done
# Hattrick is done
# Heroine is done
# Himmatwala is done
# Husbands in Goa is done
# Jatts in Golmaal is done
# Kai Po Che! is done
# Kalakalappu is done
# Katt Williams: The Pimp Chronicles: Pt. 1 is done
# Katti Batti is done
# Life in a ... Metro is done
# Marc Maron: Thinky Pain is done
# Morris from America is done
# Mumbai Meri Jaan is done
# Mundeyan Ton Bachke Rahin is done
# No One Killed Jessica is done
# Oye Lucky! Lucky Oye! is done
# Paan Singh Tomar is done
# Raja Natwarlal is done
# Satyagraha is done
# Settai is done
# Sigaram Thodu is done
# Sommore: The Reign Continues is done
# Stink! is done
# The Tigers of Scotland is done
# The Untold Tales of Armistead Maupin is done
# Transcendence is done
# Vaya is done
# Welcome to Sajjanpur is done
# Yeh Hai Bakrapur is done
# Zokkomon is done
# Gun City is done
# Heneral Luna is done
# My Brother ... Nikhil is done
# Shorgul is done
# Siddhant is done
# The Jungle School is done
# Kings is done
# Equals is done
# 14 Cameras is done
# Dragon Tiger Gate is done
# Been So Long is done
# Dovlatov is done
# Incoming is done
# Jefe is done
# Santo Cachón is done
# Shirkers is done
# W/O Ram is done
# Ronnie Coleman: The King is done
# Baahubali: The Beginning (English Version) is done
# ADAM SANDLER 100% FRESH is done
# Scorpion King 5: Book of Souls is done
# God Knows Where I Am is done
# The Rainbow Troops is done
# How to Get Over a Breakup is done
# The Gospel of John is done
# Club de Cuervos Presents: I, Potro is done
# Derren Brown: Sacrifice is done
# Gnome Alone is done
# Illang: The Wolf Brigade is done
# Naa Bangaaru Talli is done
# Oddbods: Party Monsters is done
# S Storm is done
# The Gospel of Luke is done
# The Gospel of Mark is done
# The Gospel of Matthew is done
# The Night Comes for Us is done
# Mr. Chandramouli is done
# My Babysitter's a Vampire: The Movie is done
# Ron White: If You Quit Listening, I'll Shut Up is done
# Meghnadbodh Rohoshyo is done
# Sanju is done
# Soorma is done
# Apostle is done
# Errementari: The Blacksmith and the Devil is done
# ...
# Tunisian Victory is done
# Undercover: How to Operate Behind Enemy Lines is done
# Why We Fight: The Battle of Russia is done
# WWII: Report from the Aleutians is done
# Backcountry is done
# Colkatay Columbus is done
# Officer Downe is done
# Jo Koy: Live from Seattle is done
# Blood Money is done
# Felipe Neto: My Life Makes No Sense is done
# The C Word is done
# The Most Hated Woman in America is done
# Welcome to New York is done
# Another Forever is done
# Fire at Sea is done
# Sacro GRA is done
# Best Worst Thing That Ever Could Have Happened is done
# Train to Busan is done
# Deidra & Laney Rob a Train is done
# Naledi: A Baby Elephant's Tale is done
# Pandora is done
# 5 to 7 is done
# Coraline is done
# Howards End is done
# The Hollow Point is done
# The Riot Club is done
# Asoka is done
# Bon Cop, Bad Cop is done
# Les Bleus - Une autre histoire de France, 1996-2016 is done
# Namour is done
# Notes on Blindness is done
# One 2 Ka 4 is done
# Ottaal is done
# Sunrise is done
# Angry Indian Goddesses is done
# Jim Norton: Mouthful of Shame is done
# 100 Meters is done
# Bana Masal Anlatma is done
# Berlin Kaplani is done
# Burning Sands is done
# Çarsi Pazar is done
# Çok Filim Hareketler Bunlar is done
# Dedemin Fisi is done
# Deliha is done
# Düğün Dernek is done
# Dügün Dernek 2: Sünnet is done
# Eyyvah Eyyvah is done
# Eyyvah Eyyvah 2 is done
# Eyyvah Eyyvah 3 is done
# G.O.R.A is done
# Hayat Öpücügü is done
# Hokkabaz is done
# Hükümet Kadin is done
# Hükümet Kadin 2 is done
# Incir Receli 2 is done
# Kara Bela is done
# Kocan Kadar Konus is done
# Kocan Kadar Konus 2: Dirilis is done
# Kurtulus Son Durak is done
# Mucize is done
# Niyazi Gül Dörtnala is done
# Patron Mutlu Son Istiyor is done
# Refugee is done
# Romantik Komedi is done
# Romantik Komedi 2: Bekarlığa Veda is done
# Sadece Sen is done
# Sen Kimsin? is done
# The Boss's Daughter is done
# The Butterfly's Dream is done
# Vizontele is done
# Vizontele Tuuba is done
# Match is done
# Peter and the Farm is done
# The Sunshine Makers is done
# The Young Offenders is done
# Thithi is done
# The Waterboy is done
# Amy Schumer: The Leather Special is done
# Danny Says is done
# The Salvation is done
# Beak & Brain: Genius Birds From Down Under is done
# Beary Tales is done
# Chandani: The Daughter of the Elephant Whisperer is done
# Koko: The Gorilla Who Talks is done
# Nature: Raising the Dinosaur Giant is done
# Nila is done
# Revelations is done
# Sustainable is done
# Tiger is done
# Ugly is done
# Vikings Unearthed is done
# Be Here Now is done
# Mike Birbiglia: Thank God for Jokes is done
# People You May Know is done
# Force 2 is done
# Jonas is done
# Operações Especiais is done
# I Don't Feel at Home in This World Anymore is done
# Kill Command is done
# The Lovers and the Despot is done
# Magnus is done
# Secrets of Chatsworth is done
# Secrets of Henry VIII's Palace: Hampton Court is done
# Secrets of Her Majesty's Secret Service is done
# Secrets of Highclere Castle is done
# Secrets of the Tower of London is done
# Trevor Noah: Afraid of the Dark is done
# Mirzya is done
# Boy Missing is done
# Growing Up Wild is done
# Tini: The New Life of Violetta is done
# GANTZ:O is done
# INDIA is done
# Kill Ratio is done
# Madaari is done
# Rocky Handsome is done
# TE3N is done
# Milk is done
# Operator is done
# A Heavy Heart is done
# Aram, Aram is done
# La Coppia dei Campioni is done
# Rush: Beyond the Lighted Stage is done
# The Fury of a Patient Man is done
# The Memory of Water is done
# Girlfriend's Day is done
# Katherine Ryan: In Trouble is done
# Me and the Alien is done
# Clouds of Sils Maria is done
# Stronger Than the World is done
# David Brent: Life on the Road is done
# Grillo vs Grillo is done
# Hitler - A Career is done
# Blinky Bill: The Movie is done
# Happy Times is done
# Jack and the Cuckoo-Clock Heart is done
# Michael Bolton's Big, Sexy Valentine's Day Special is done
# Naga The Eternal Yogi is done
# Star Men is done
# The Lovers is done
# The Charnel House is done
# Daniel Sosa: Sosafado is done
# Imperial Dreams is done
# Trash Fire is done
# Chauthi Koot is done
# Dilwale is done
# Gun Runners is done
# Happy New Year is done
# Haraamkhor is done
# Heroes Wanted is done
# Highly Strung is done
# I Am Sun Mu is done
# Indiscretion is done
# La Última Fiesta is done
# Maroon is done
# Paris Is Burning is done
# The Hurt Business is done
# The Reconquest is done
# Zapped is done
# Bill Burr: Walk Your Way Out is done
# Semana Santa is done
# Journey to Greenland is done
# IBOY is done
# O Silêncio do Céu is done
# Cristela Alonzo: Lower Classy is done
# Gad Gone Wild is done
# Caida del Cielo is done
# Pink is done
# Take the 10 is done
# Good Kids is done
# Enlighten Us is done
# Neal Brennan: 3 Mics is done
# Roger Corman's Death Race 2050 is done
# Flash of Genius is done
# The Rezort is done
# Berlin Calling is done
# Harry and Snowman is done
# Hostage to the Devil is done
# Max Rose is done
# Sarajevo is done
# Stereo is done
# Teenage Cocktail is done
# The Similars is done
# Twisted Trunk, Big Fat Body is done
# We Are Young. We Are Strong. is done
# Camp X-Ray is done
# Estar o no estar is done
# Little Sister is done
# The River Thief is done
# Aquarius is done
# Casablancas: The Man Who Loved Women is done
# Clinical is done
# Little Men is done
# Very Big Shot is done
# Jim Gaffigan: Cinco is done
# Under the Shadow is done
# Coin Heist is done
# LEGO: Marvel Super Heroes: Maximum Overload is done
# Rustom is done
# Rampage: President Down is done
# Marvel's Hulk: Where Monsters Dwell is done
# Jen Kirkman: Just Keep Livin’? is done
# Autohead is done
# Bee Movie is done
# Headwinds is done
# Udta Punjab is done
# Mr. Pig is done
# The NSU-Complex is done
# 7:19 is done
# Garfunkel and Oates: Trying to be Special is done
# A Christmas Special: Miraculous: Tales of Ladybug & Cat Noir is done
# Gabriel lglesias: I’m Sorry For What I Said When I Was Hungry is done
# Barry is done
# Sister Cities is done
# Theo Who Lived is done
# 3 Türken & ein Baby is done
# Eddie - Strongman is done
# Sand Storm is done
# Ricardo O'Farrill: Abrazo navideño is done
# Asperger's Are Us is done
# Mariah Carey's Merriest Christmas is done
# Spectral is done
# Kickboxer: Vengeance is done
# Other People is done
# Blue Jay is done
# One in a Billion is done
# Reggie Watts: Spatial is done
# Mercenary is done
# For the Love of Spock is done
# White Girl is done
# #Rucker50 is done
# 1000 Rupee Note is done
# Across Grace Alley is done
# Asu Mare 2 is done
# Interrogation is done
# Natural Selection is done
# Rainbow Time is done
# Richard Pryor: Live in Concert is done
# Tellur Aliens is done
# The Violin Player is done
# Yo-Kai Watch: The Movie is done
# When Two Worlds Collide is done
# Beauties of the Night is done
# Michael Che Matters is done
# Ludo is done
# Mercy is done
# The Land of Cards is done
# Carlos Ballarta: El amor es de putos is done
# Donald Glover: Weirdo is done
# Colin Quinn: The New York Story is done
# Divines is done
# Sour Grapes is done
# Dieter Nuhr: Nuhr in Berlin is done
# Mumbai Cha Raja is done
# True Memoirs of an International Assassin is done
# Kathleen Madigan: Bothering Jesus is done
# My Way is done
# Dana Carvey: Straight White Male, 60 is done
# The Ivory Game is done
# Thorne: Scaredy Cat is done
# Thorne: Sleepyhead is done
# A Grand Night In: The Story of Aardman is done
# Norman Lear: Just Another Version of You is done
# Santa Pac's Merry Berry Day is done
# Spanish Affair 2 is done
# The Interview is done
# The Last Days of Chez Nous is done
# Tree Man is done
# Winter of Our Dreams is done
# Young Tiger is done
# Pup Star is done
# I Am the Pretty Thing That Lives in the House is done
# Into the Inferno is done
# The African Doctor is done
# They Are Everywhere is done
# West Coast is done
# 7 años is done
# Joe Rogan: Triggered is done
# A Family Affair is done
# A Mighty Team is done
# Berserk: The Golden Age Arc I - The Egg of the King is done
# Bleach The Movie: Fade to Black is done
# Bleach the Movie: Hell Verse is done
# Blind Date is done
# Naruto Shippûden the Movie: Bonds is done
# Naruto Shippuden: The Movie is done
# Sky Ladder: The Art of Cai Guo-Qiang is done
# Mascots is done
# Justin Timberlake + the Tennessee Kids is done
# 13TH is done
# Russell Peters: Almost Famous is done
# The Siege of Jadotville is done
# LEGO Jurassic World: The Indominus Escape is done
# Bombshell is done
# Chatô: The King of Brazil is done
# Harud is done
# Much Ado About Nothing is done
# My Big Night is done
# My Little Pony Equestria Girls: Legend of Everfree is done
# Pac's Scary Halloween is done
# Riphagen - The Untouchable is done
# Umrika is done
# Unchained: The Untold Story of Freestyle Motocross is done
# Welcome Mr. President is done
# Amanda Knox is done
# Audrie & Daisy is done
# Iliza Shlesinger: Confirmed Kills is done
# The First Line is done
# Karol Modzelewski, Łukasz „Lotek” Lodkowski No Offense is done
# Katarzyna Piasecka, Rafał Pacześ Seriously Funny is done
# Mariusz Kałamaga, Karol Kopiec, Wiolka Walaszczyk Hilarious Trio is done
# Rafał Banaś, Michał Leja Laugh out Loud is done
# The Best of Rafał Rutkowski Olka Szczęśniak is done
# Tomasz Jachimek, Jacek Stramik Laugh at Live is done
# ARQ is done
# Cedric the Entertainer: Live from the Ville is done
# Raiders!: The Story of the Greatest Fan Film Ever Made is done
# The White Helmets is done
# Natural Born Pranksters is done
# Sample This is done
# Extremis is done
# Jandino: Whatever it Takes is done
# Elstree 1976 is done
# A Noble Intention is done
# Bon Bini Holland is done
# Dukhtar is done
# Figaro Pho is done
# Full Out is done
# Holy Hell is done
# Off Course is done
# Saudi Arabia Uncovered is done
# We Need to Talk is done
# Blue Is the Warmest Color is done
# Jeff Foxworthy and Larry the Cable Guy: We’ve Been Thinking... is done
# XOXO is done
# Abzurdah is done
# Dhanak is done
# I'll Sleep When I'm Dead is done
# Being AP is done
# John & Jane is done
# Real Crime: Supermarket Heist (Tesco Bomber) is done
# 13 Cameras is done
# Jim Gaffigan: Beyond the Pale is done
# Jim Gaffigan: King Baby is done
# Jim Gaffigan: Mr. Universe is done
# Jim Gaffigan: Obsessed is done
# David Cross: Making America Great Again! is done
# The Little Prince is done
# Lavell Crawford: Can a Brother Get Some Love? is done
# APEX: The Story of the Hypercar is done
# Children of God is done
# Hitler's Olympics is done
# Holding the Man is done
# How to Win the US Presidency is done
# Interview with a Serial Killer is done
# Real Crime: Diamond Geezers is done
# Tallulah is done
# Lizzie Borden Took an Ax is done
# Internet Famous is done
# Holidays is done
# Lusers is done
# Rebirth is done
# Tony Robbins: I Am Not Your Guru is done
# Gridlocked is done
# Summer of '92 is done
# The Invitation is done
# Brahman Naman is done
# Jim Jefferies: Freedumb is done
# King Jack is done
# Road to Yesterday is done
# Suicide (Hitabdut) is done
# X: Past Is Present is done
# You Carry Me is done
# (T)ERROR is done
# Palio is done
# Sofía Niño de Rivera: Exposed is done
# The Fundamentals of Caring is done
# Ip Man 3 is done
# Reincarnated is done
# Bo Burnham: Make Happy is done
# Black Man White Skin is done
# Spy Time is done
# The Fear of 13 is done
# The Heroes of Evil is done
# The Do-Over is done
# The Last Man on the Moon is done
# Attacking the Devil: Harold Evans and the Last Nazi War Crime is done
# The Chosen Ones is done
# Ali Wong: Baby Cobra is done
# 4th Man Out is done
# Mark Gatiss: A Study in Sherlock is done
# Palm Trees in the Snow is done
# Terra is done
# Special Correspondents is done
# Team Foxcatcher is done
# Democrats is done
# Catching the Sun is done
# Patton Oswalt: Talking for Clapping is done
# Mac & Devin Go to High School is done
# Band of Robbers is done
# Belgica is done
# Prescription Thugs is done
# Look Who's Back is done
# Hush is done
# Frank and Cindy is done
# Frank and Cindy is done
# Iverson is done
# Jeremy Scott: The People's Designer is done
# Covered: Alive in Asia is done
# Kung Fu Panda: Secrets of the Scroll is done
# Monkey Up is done
# He Never Died is done
# Jimmy Carr: Funny Business is done
# My Beautiful Broken Brain is done
# Pee-wee's Big Holiday is done
# Chicken Little is done
# Zinzana is done
# Halo: The Fall of Reach is done
# For Grace is done
# Blue Mountain State: The Rise of Thadland is done
# Hot Bot is done
# It's Now or Never is done
# Retribution is done
# Crouching Tiger, Hidden Dragon: Sword of Destiny is done
# The Look of Silence is done
# Marvel Super Hero Adventures: Frost Fight! is done
# Abominable Christmas is done
# Dear Dracula is done
# Sister Code is done
# Lila & Eve is done
# Hannibal Buress: Comedy Camisado is done
# French Dirty is done
# Ricardo O'Farrill Abrazo Genial is done
# Ip Man is done
# Ip Man 2 is done
# Tom Segura: Mostly Stories is done
# How to Change the World is done
# Power Rangers Samurai: Christmas Together, Friends Forever (Christmas Special) is done
# Power Rangers Samurai: Clash of the Red Rangers is done
# Power Rangers Samurai: Party Monsters (Halloween Special) is done
# Power Rangers Super Megaforce: The Legendary Battle (Extended) is done
# Power Rangers Super Samurai: Stuck on Christmas is done
# Power Rangers Super Samurai: Trickster Treat is done
# Power Rangers: Megaforce: Raising Spirits is done
# Power Rangers: Megaforce: The Robo Knight Before Christmas is done
# Fifty is done
# Marco Polo: One Hundred Eyes is done
# Fireplace 4K: Classic Crackling Fireplace from Fireplace for Your Home is done
# Fireplace 4K: Crackling Birchwood from Fireplace for Your Home is done
# Magic Snowflake is done
# Santa's Apprentice is done
# Mike Epps: Don't Take It Personal is done
# Bob's Broken Sleigh is done
# This Was Tomorrow is done
# The Ridiculous 6 is done
# Trailer Park Boys: Drunk, High and Unemployed: Live in Austin is done
# A Very Murray Christmas is done
# My Little Pony Equestria Girls: Friendship Games is done
# Tyke Elephant Outlaw is done
# Naomi and Ely's No Kiss List is done
# John Mulaney: The Comeback Kid is done
# Kristy is done
# Manson Family Vacation is done
# Walt Disney Animation Studios Short Films Collection is done
# Results is done
# Anthony Jeselnik: Thoughts and Prayers is done
# Beasts of No Nation is done
# Circle is done
# Suburra is done
# Winter on Fire: Ukraine's Fight for Freedom is done
# Anjelah Johnson: Not Fancy is done
# SMOSH: The Movie is done
# Keith Richards: Under the Influence is done
# Cowspiracy: The Sustainability Secret is done
# 6 Years is done
# Miss Julie is done
# Demetri Martin: Live (At the Time) is done
# Yellowbird is done
# Tig is done
# The Physician is done
# Creep is done
# Chris Tucker Live is done
# Ralphie May: Imperfectly Yours is done
# What Happened, Miss Simone? is done
# Advantageous is done
# The Perfect Dictatorship is done
# Hot Girls Wanted is done
# Jen Kirkman: I'm Gonna Die Alone (And I Feel Fine) is done
# The Other One: The Long Strange Trip of Bob Weir is done
# Tinker Bell and the Legend of the NeverBeast is done
# Russell Madness is done
# Chris D'Elia: Incorrigible is done
# Marvel & ESPN Films Present: 1 of 1: Genesis is done
# Aziz Ansari Live at Madison Square Garden is done
# My Own Man is done
# Ralphie May: Unruly is done
# Stop at Nothing: The Lance Armstrong Story is done
# Virunga: Gorillas in Peril is done
# Iliza Shlesinger: Freezing Hot is done
# BoJack Horseman Christmas Special: Sabrina's Christmas Wish is done
# Pee-wee's Playhouse: Christmas Special is done
# My Little Pony Equestria Girls: Rainbow Rocks is done
# Get Santa is done
# Bill Burr: I'm Sorry You Feel That Way is done
# Chelsea Peretti: One of the Greats is done
# Virunga is done
# E-Team is done
# Wyatt Cenac: Brooklyn is done
# Iron Man & Captain America: Heroes United is done
# Chelsea Handler: Uganda Be Kidding Me Live is done
# Print the Legend is done
# Mission Blue is done
# The Battered Bastards of Baseball is done
# The Pirate Fairy is done
# From One Second to the Next is done
# Marvel's Iron Man & Hulk: Heroes United is done
# Mitt is done
# The Square is done
# Shrek the Musical is done
# The Short Game is done
# A Russell Peters Christmas is done
# Aziz Ansari: Buried Alive is done
# Russell Peters: Notorious is done
# Iliza Shlesinger: War Paint is done
# Kung Fu Panda: Holiday is done
# Casa de mi Padre is done
# Being Elmo: A Puppeteer's Journey is done
# A Stoning in Fulham County is done
# Adam: His Song Continues is done
# Hard Lessons is done
# In Defense of a Married Man is done
# Quiet Victory: The Charlie Wedemeyer Story is done
# Strange Voices is done
# The Ryan White Story is done
# Too Young the Hero is done
# Triumph of the Heart is done
# Unspeakable Acts is done
# Victim of Beauty is done
# Joseph: King of Dreams is done
# Even the Rain is done
# Mad Ron's Prevues from Hell is done
# Splatter is done
# Just Another Love Story is done
# To and From New York is done

# %% [markdown]
# # Scrape Flixable Netflix TV shows

# %%
page_iterations = list(range(1,49))
all_tv = []

for iteration_count in page_iterations:

    page = requests.get('https://flixable.com/genre/tv-shows/?min-rating=0&min-year=1920&max-year=2020&order=date&page={}'.format(iteration_count))
    soup = BeautifulSoup(page.content, 'html.parser')
    table = soup.find_all('div', attrs={'class': 'col-sm-6 col-lg-3 mb-3'})

    for entry in table:
        try:
            href = entry.find('a', attrs={'class':'poster-link'})['href']
            page2 = requests.get(f'https://flixable.com{href}')
            soup2 = BeautifulSoup(page2.content, 'html.parser')

            #title
            title = soup2.find('h1', attrs={'class':'mb-3'}).get_text().strip()
            #image
            image = soup2.find('img', attrs={'class':'poster mb-4'})['src']
            #year
            year = soup2.find('span', attrs={'class':'mr-2'}).get_text()

            row = soup2.find('div', attrs={'class':'mb-2'})

            movie_traits = row.find_all('span')
            # release year
            release_year = movie_traits[0].get_text()
            # rating
            rating = movie_traits[1].get_text()
            # runtime
            runtime = movie_traits[2].get_text()

            movie_box = soup2.find('div', attrs={'class':'col-md-8'})
            # movie plot
            plot = movie_box.find('div', attrs={'class':'mb-3'}).get_text().strip()
            # movie genres
            genres = movie_box.find_all('div', attrs={'class':'mb-2'})[1].get_text()
            movie_genres = genres.replace('Genres:','').replace(',','').replace('Movies','').replace('&','').strip().split()

            #add to dictionary
            full_movie_entry = {'title':title, 'image':image, 'year':year, 
                                'release_year':release_year, 'rating':rating, 'runtime':runtime,
                                'plot':plot, 'genres':movie_genres}

            all_tv.append(full_movie_entry)
            print('{} is done'.format(title))
        except:
            pass

f = open("tv.csv", "w")
writer = csv.DictWriter(f, fieldnames=['title', 'image', 'year', 'release_year', 'rating', 'runtime', 'plot', 'genres'])
writer.writeheader()
writer.writerows(all_tv)
f.close()
# Out:
# Cheer is done
# Dracula is done
# Go! Go! Cory Carson is done
# Anne with an E is done
# Sex, Explained is done
# Thieves of the Wood is done
# Because This Is My First Life is done
# Border Security: America's Front Line is done
# Cells at Work! is done
# Chhota Bheem Kung Fu Dhamaka Series is done
# Drugs, Inc. is done
# Live Up To Your Name is done
# Messiah is done
# Mia and Me is done
# Nisman: The Prosecutor, the President, and the Spy is done
# Oddbods is done
# Reply 1988 is done
# Rurouni Kenshin is done
# Saint Seiya is done
# Save Me is done
# The Bride of Habaek is done
# The Circle is done
# ARASHI's Diary -Voyage- is done
# Good Girls is done
# Occupied is done
# Pucca: Love Recipe is done
# Rainbow Ruby is done
# The Degenerates is done
# Alexa & Katie is done
# The Gift is done
# The Bonfire of Destiny is done
# CAROLE & TUESDAY is done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-280-53f5678e800b> in <module>
#       4 for iteration_count in page_iterations:
#       5
# ----> 6     page = requests.get('https://flixable.com/genre/tv-shows/?min-rating=0&min-year=1920&max-year=2020&order=date&page={}'.format(iteration_count))
#       7     soup = BeautifulSoup(page.content, 'html.parser')
#       8     table = soup.find_all('div', attrs={'class': 'col-sm-6 col-lg-3 mb-3'})
#
# //anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# //anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# //anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# //anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# //anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     299     def connect(self):
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#     303
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     157         try:
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#     161         except SocketTimeout as e:
#
# //anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      68             if source_address:
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#      72
#
# KeyboardInterrupt:
